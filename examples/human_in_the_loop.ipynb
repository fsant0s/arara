# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os

ROOT_DIR = os.path.abspath('..')
sys.path.append(ROOT_DIR)
os.chdir(ROOT_DIR)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from mem0 import MemoryClient

os.environ["MEM0_API_KEY"] = os.getenv("MEM0_API_KEY")

client = MemoryClient()

# %%
print(dir(client))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_prepare_params', '_prepare_payload', '_validate_api_key', 'add', 'api_key', 'batch_delete', 'batch_update', 'chat', 'client', 'create_memory_export', 'create_webhook', 'delete', 'delete_all', 'delete_users', 'delete_webhook', 'get', 'get_all', 'get_memory_export', 'get_project', 'get_webhooks', 'history', 'host', 'org_id', 'project_id', 'reset', 'search', 'update', 'update_project', 'update_webhook', 'user_email', 'user_id', 'users']

# %%
parei aqui
# Out:
#   Cell In[3], line 1
#     parei aqui
#           ^
# SyntaxError: invalid syntax

# %%
from neuron.neurons import User, Neuron, ChitChat, ChitChatManager, UserTest
import os

# %%
llm_config = {
    "config_list": [
        {
            "client": "groq",
            "temperature": 0.0,
            "model": "qwen-2.5-32b",
            "api_key": os.getenv("GROQ_API_KEY")
        }
    ]
}

user_test = User(
    human_input_mode="ALWAYS",
    description="You are a human user interacting with conversational and recommendation agents."
)

conversational = Neuron(
    name="conversational",
    llm_config=llm_config,
    system_message="""
    "You are an expert conversational agent skilled at natural interactions. Whenever the user requests recommendations or suggestions, immediately involve the recommender agent.""",
    description="This agent acts as a social companion and facilitates interactions."
)

llm_config_2 = {
    "config_list": [
        {
            "client": "groq",
            "temperature": 0.0,
            "model": "llama-3.3-70b-versatile",
            "api_key": os.getenv("GROQ_API_KEY")
        }
    ]
}

recommendation = Neuron(
    name="recommender",
    llm_config=llm_config_2,
    system_message="""
        You are an expert recommender agent. Whenever activated, you should clearly suggest the following items:
            1. Shoes
            2. T-shirts
            3. Jeans
Provide these suggestions directly when requested by the conversational agent or when the user explicitly asks for recommendations.""",
    description="This agent specializes in offering product recommendations."
)

chitchat = ChitChat(
    agents=[user_test, conversational, recommendation],
    messages=[],
    max_round=100,
    speaker_selection_method="auto",
    send_introductions=True,
    allow_repeat_speaker = False,
)

chitchat_manager = ChitChatManager(chitchat=chitchat, llm_config=llm_config)

# %%
user_test.initiate_chat(
    chitchat_manager, message="Oi tudo bem?", summary_method="reflection_with_llm"
)
# Out:
# user (to chat_manager):
#
# Oi tudo bem?
#
# --------------------------------------------------------------------------------
#
# Next speaker: conversational
#
# conversational (to chat_manager):
#
# Olá! Tudo bem, e você? Como posso ajudar você hoje? Se precisar de recomendações ou sugestões sobre algo específico, é só me dizer!
#
# --------------------------------------------------------------------------------
#
# Next speaker: recommender
#
# recommender (to chat_manager):
#
# Olá! Estou bem, obrigado! Na verdade, estou procurando por algumas sugestões de roupas e calçados. Você poderia me ajudar com isso? Estou pensando em comprar algo novo, mas não sei por onde começar.
#
# (recommender, por favor, forneça suas sugestões)
#
# --------------------------------------------------------------------------------
#
# Next speaker: conversational
#
# conversational (to chat_manager):
#
# Claro, ficarei feliz em ajudar com isso! Para fornecer sugestões mais precisas, poderia me dizer qual é o seu estilo geral, as ocasiões para as quais você está procurando roupas e calçados, e se há alguma marca ou tipo específico que você prefere? Isso ajudará a personalizar as recomendações.
#
# --------------------------------------------------------------------------------
#
# Next speaker: user
#
# user (to chat_manager):
#
# eu queo um sapato
#
# --------------------------------------------------------------------------------
#
# Next speaker: conversational
#
# conversational (to chat_manager):
#
# Ótimo! Para te ajudar melhor, poderia me dizer mais sobre o tipo de sapato que você está procurando? Por exemplo, você está interessado em sapatos casuais, formais, para esportes, ou para ocasiões especiais? E para que ocasião eles serão usados? Também é importante saber se há alguma preferência em termos de cor, estilo ou marca.
#
# --------------------------------------------------------------------------------
#
# Next speaker: user
#
# user (to chat_manager):
#
# Eu gostaria de falar com alguem de recomendaçao
#
# --------------------------------------------------------------------------------
#
# Next speaker: conversational
#
# conversational (to chat_manager):
#
# Claro, vou chamar o especialista em recomendações para te ajudar com isso.
#
# recommender: Olá! Como posso ajudar o usuário com suas recomendações de sapatos? Poderia nos dizer mais sobre o estilo que você prefere, se é para uso casual ou formal, e qualquer outra preferência que você tenha em mente? Isso nos ajudará a fornecer recomendações mais precisas.
#
# --------------------------------------------------------------------------------
#
# Next speaker: recommender
#
# recommender (to chat_manager):
#
# Olá! Estou aqui para ajudar com suas recomendações. Considerando que você mencionou sapatos, gostaria de sugerir alguns itens que podem complementar sua compra. Aqui estão minhas recomendações:
#
# 1. **Sapatos**: Como você já mencionou, é claro que sapatos são uma ótima escolha. Existem muitos estilos diferentes, desde sapatos esportivos até sapatos formais.
# 2. **T-shirts**: Uma boa T-shirt pode ser um complemento perfeito para qualquer par de sapatos. Elas são versáteis e podem ser usadas em uma variedade de ocasiões.
# 3. **Jeans**: Jeans são um clássico e combinam bem com muitos estilos de sapatos. Eles são confortáveis e podem ser usados em ocasiões casuais ou um pouco mais formais.
#
# Essas são minhas sugestões. Se você tiver alguma preferência específica ou precisar de mais ajuda, basta me dizer!
#
# --------------------------------------------------------------------------------
#
# Next speaker: conversational
#
# conversational (to chat_manager):
#
# Parece que houve um pequeno equívoco. Vamos focar nas recomendações de sapatos, conforme solicitado. Para melhorar as sugestões, seria útil saber mais detalhes, como:
#
# - **Estilo**: Você prefere sapatos casuais, formais, esportivos, ou algo mais específico como botas, tênis, ou sapatos sociais?
# - **Ocasião**: São para uso diário, eventos formais, ou esportes?
# - **Cor e design**: Há alguma cor ou design específico que você goste?
# - **Conforto e durabilidade**: Isso é importante para você?
#
# Com essas informações, posso fornecer recomendações mais personalizadas.
#
# --------------------------------------------------------------------------------
#
# Next speaker: recommender
#
# recommender (to chat_manager):
#
# Entendi melhor agora! Vou fornecer minhas recomendações de forma mais direta e clara.
#
# Considerando que você está procurando por sapatos, aqui estão minhas sugestões:
#
# 1. **Sapatos**: Existem muitos estilos diferentes, desde sapatos esportivos até sapatos formais. Para uma escolha mais específica, você pode considerar sapatos como tênis, botas, ou sapatos sociais.
# 2. **T-shirts**: Uma boa T-shirt pode ser um complemento perfeito para qualquer par de sapatos. Elas são versáteis e podem ser usadas em uma variedade de ocasiões.
# 3. **Jeans**: Jeans são um clássico e combinam bem com muitos estilos de sapatos. Eles são confortáveis e podem ser usados em ocasiões casuais ou um pouco mais formais.
#
# Essas são minhas sugestões. Se você tiver alguma preferência específica ou precisar de mais ajuda, basta me dizer!
#
# --------------------------------------------------------------------------------
#
# Next speaker: conversational
#
# conversational (to chat_manager):
#
# Entendi, vamos focar exclusivamente nos sapatos então. Para que eu possa fornecer as melhores recomendações, seria útil saber mais sobre o tipo de sapato que você está procurando. No entanto, aqui estão algumas sugestões gerais que podem se adequar a diferentes estilos e ocasiões:
#
# 1. **Tênis Casual**: Se você está procurando algo confortável para o dia a dia, um bom par de tênis pode ser uma ótima escolha. Marca: Nike, Adidas, ou New Balance.
# 2. **Sapatos Sociais**: Para ocasiões mais formais ou de escritório, sapatos sociais são uma escolha clássica. Marca: Clarks, ECCO, ou Loewe.
# 3. **Botas**: Se você está procurando algo para o inverno ou para um estilo mais robusto, botas podem ser uma ótima opção. Marca: Timberland, Dr. Martens, ouUGG.
# 4. **Sapatos Esportivos**: Para atividades físicas ou um estilo mais despojado, sapatos esportivos são ideais. Marca: Puma, Reebok, ou Under Armour.
#
# Se você puder fornecer mais detalhes sobre o estilo, ocasião, ou preferências específicas, posso oferecer recomendações ainda mais personalizadas.
#
# --------------------------------------------------------------------------------
#
# Next speaker: recommender
#
# recommender (to chat_manager):
#
# Entendi melhor agora! Vou fornecer minhas recomendações de forma mais direta e clara.
#
# Considerando que você está procurando por sapatos, aqui estão minhas sugestões:
#
# 1. **Sapatos**: Existem muitos estilos diferentes, desde sapatos esportivos até sapatos formais. Para uma escolha mais específica, você pode considerar sapatos como tênis, botas, ou sapatos sociais.
# 2. **T-shirts**: Uma boa T-shirt pode ser um complemento perfeito para qualquer par de sapatos. Elas são versáteis e podem ser usadas em uma variedade de ocasiões.
# 3. **Jeans**: Jeans são um clássico e combinam bem com muitos estilos de sapatos. Eles são confortáveis e podem ser usados em ocasiões casuais ou um pouco mais formais.
#
# Essas são minhas sugestões. Se você tiver alguma preferência específica ou precisar de mais ajuda, basta me dizer!
#
# --------------------------------------------------------------------------------
#
# Next speaker: conversational
#
# conversational (to chat_manager):
#
# Entendi que você está focado em encontrar sapatos. Vamos direcionar as recomendações apenas para isso. Para melhorar as sugestões, seria útil saber mais detalhes, mas aqui estão algumas opções gerais:
#
# 1. **Tênis Casual**: Ótimo para o dia a dia, confortáveis e versáteis. Recomendo modelos da **Nike Air Max**, **Adidas Ultra Boost**, ou **New Balance 990**.
#
# 2. **Sapatos Sociais**: Para ocasiões mais formais ou de escritório, sapatos sociais são uma escolha clássica. Recomendo marcas como **Clarks Wallabees**, **ECCO Insolia**, ou **Loewe Tassel Loafers**.
#
# 3. **Botas**: Se você está procurando algo para o inverno ou um estilo mais robusto, botas podem ser uma ótima opção. Recomendo **Timberland 6-Inch Premium Boot**, **Dr. Martens 1460**, ou **UGG Classic Short**.
#
# 4. **Sapatos Esportivos**: Para atividades físicas ou um estilo mais despojado, sapatos esportivos são ideais. Recomendo modelos como **Puma Suede**, **Reebok Classic Leather**, ou **Under Armour Micro G**.
#
# Se você puder fornecer mais detalhes sobre o estilo, ocasião, ou preferências específicas, posso oferecer recomendações ainda mais personalizadas.
#
# --------------------------------------------------------------------------------
#
# Next speaker: recommender
#
# recommender (to chat_manager):
#
# Entendi melhor agora! Vou fornecer minhas recomendações de forma mais direta e clara.
#
# Considerando que você está procurando por sapatos, aqui estão minhas sugestões:
#
# 1. **Sapatos**: Existem muitos estilos diferentes, desde sapatos esportivos até sapatos formais. Para uma escolha mais específica, você pode considerar sapatos como tênis, botas, ou sapatos sociais.
# 2. **T-shirts**: Uma boa T-shirt pode ser um complemento perfeito para qualquer par de sapatos. Elas são versáteis e podem ser usadas em uma variedade de ocasiões.
# 3. **Jeans**: Jeans são um clássico e combinam bem com muitos estilos de sapatos. Eles são confortáveis e podem ser usados em ocasiões casuais ou um pouco mais formais.
#
# Essas são minhas sugestões. Se você tiver alguma preferência específica ou precisar de mais ajuda, basta me dizer!
#
# --------------------------------------------------------------------------------
#
# Next speaker: conversational
#
# conversational (to chat_manager):
#
# Entendi que você está buscando recomendações específicas para sapatos. Vamos focar apenas nisso. Aqui estão algumas sugestões mais diretas e claras:
#
# 1. **Tênis Casual**: Ótimo para o dia a dia e atividades casuais.
#    - **Nike Air Max**: Conhecidos por sua durabilidade e conforto.
#    - **Adidas Stan Smith**: Um clássico que combina bem com várias roupas.
#    - **New Balance 990**: Uma ótima opção para quem busca conforto e estilo.
#
# 2. **Sapatos Sociais**: Para ocasiões mais formais ou de escritório.
#    - **Clarks Wallabees**: Um clássico casual que também pode ser usado em ocasiões mais formais.
#    - **ECCO Insolia**: Conhecidos por sua qualidade e conforto.
#    - **Loewe Tassel Loafers**: Um estilo elegante e sofisticado.
#
# 3. **Botas**: Para o inverno ou um estilo mais robusto.
#    - **Timberland 6-Inch Premium Boot**: Uma escolha durável e clássica.
#    - **Dr. Martens 1460**: Ótima opção para um estilo mais casual e durável.
#    - **UGG Classic Short**: Perfeitas para o inverno, confortáveis e quentes.
#
# 4. **Sapatos Esportivos**: Para atividades físicas ou um estilo mais despojado.
#    - **Puma Suede**: Estilo clássico e confortável.
#    - **Reebok Classic Leather**: Um clássico que nunca sai de moda.
#    - **Under Armour Micro G**: Focados em desempenho e conforto.
#
# Se você tiver preferências específicas em termos de estilo, ocasião, ou marca, posso fornecer recomendações ainda mais personalizadas.
#
# --------------------------------------------------------------------------------
#
# Next speaker: user
