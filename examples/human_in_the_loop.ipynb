# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os

ROOT_DIR = os.path.abspath('..')
sys.path.append(ROOT_DIR)
os.chdir(ROOT_DIR)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from neuron.neurons import User, Neuron, ChitChat, ChitChatManager, UserTest

# %%
import os

llm_config = {
    "config_list": [
        {
            "client": "groq",
            "temperature": 0.0,
            "model": "qwen-2.5-32b",
            "api_key": os.getenv("GROQ_API_KEY")
        }
    ]
}

user_test = UserTest(
    human_input_mode="ALWAYS",
    description="You are a human user interacting with conversational and recommendation agents."
)

conversational = Neuron(
    name="conversational",
    llm_config=llm_config,
    system_message="""
    "You are an expert conversational agent skilled at natural interactions. Whenever the user requests recommendations or suggestions, immediately involve the recommender agent.""",
    description="This agent acts as a social companion and facilitates interactions."
)

llm_config_2 = {
    "config_list": [
        {
            "client": "groq",
            "temperature": 0.0,
            "model": "llama-3.3-70b-versatile",
            "api_key": os.getenv("GROQ_API_KEY")
        }
    ]
}

recommendation = Neuron(
    name="recommender",
    llm_config=llm_config_2,
    system_message="""
        You are an expert recommender agent. Whenever activated, you should clearly suggest the following items:

    1. Shoes
    2. T-shirts
    3. Jeans

Provide these suggestions directly when requested by the conversational agent or when the user explicitly asks for recommendations.""",
    description="This agent specializes in offering product recommendations."
)

chitchat = ChitChat(
    agents=[user_test, conversational, recommendation],
    messages=[],
    max_round=100,
    speaker_selection_method="random",
    send_introductions=True,
    allow_repeat_speaker = False,
)

chitchat_manager = ChitChatManager(chitchat=chitchat, llm_config=llm_config)

# %%
user_test.initiate_chat(
    chitchat_manager, message="Oi tudo bem?", summary_method="reflection_with_llm"
)
# Out:
# user_test (to chat_manager):
#
# Oi tudo bem?
#
# --------------------------------------------------------------------------------
#
# Next speaker: recommender
#
# recommender (to chat_manager):
#
# Olá. Yes, everything is fine, thanks for asking. If you're looking for some great products, I'd like to recommend the following:
# 1. Shoes - a good pair can make a big difference in your daily life.
# 2. T-shirts - they're versatile and can be dressed up or down.
# 3. Jeans - a classic choice that never goes out of style.
#
# --------------------------------------------------------------------------------
#
# Next speaker: conversational
#
# conversational (to chat_manager):
#
# It seems there was a mix-up in my previous response. To clarify, if you're looking for recommendations on specific products like shoes, t-shirts, or jeans, the recommender agent would be best suited to provide detailed suggestions based on your preferences and needs. Could you tell me more about what you're looking for or any specific preferences you have?
#
# --------------------------------------------------------------------------------
#
# Next speaker: recommender
#
# recommender (to chat_manager):
#
# I'm here to help with recommendations. Since you're open to suggestions, I'd like to recommend the following essential items:
# 1. Shoes - a comfortable and stylish pair can elevate your outfit.
# 2. T-shirts - they're perfect for casual wear and can be easily paired with other items.
# 3. Jeans - a classic and versatile choice that can be dressed up or down.
#
# Please let me know if you have any specific preferences, such as color, style, or occasion, and I'll be happy to provide more tailored suggestions.
#
# --------------------------------------------------------------------------------
#
# Next speaker: user_test
#
# user_test (to chat_manager):
#
# Gostaria de saber mais sobre os produtos disponiveis.
#
# --------------------------------------------------------------------------------
#
# Next speaker: conversational
#
# conversational (to chat_manager):
#
# Claro, posso ajudar com isso! Para fornecer recomendações mais precisas, poderia me dizer mais sobre o que você está procurando? Por exemplo:
#
# 1. **Calçados**: Você prefere sapatos para ocasiões formais, tênis para esportes ou sapatos casuais para o dia a dia?
# 2. **Camisetas**: Você está procurando algo casual, com estampas, ou algo mais básico e elegante?
# 3. **Jeans**: Você prefere um jeans mais justo, reto ou com um corte mais solto? E para que tipo de ocasião você pretende usar?
#
# Com essas informações, posso solicitar ao agente de recomendação que ofereça opções mais específicas e adequadas às suas necessidades.
#
# --------------------------------------------------------------------------------
#
# Next speaker: user_test
#
# user_test (to chat_manager):
#
# Gostaria de comprar um sapato.
#
# --------------------------------------------------------------------------------
#
# Next speaker: recommender
#
# recommender (to chat_manager):
#
# Entendo que você está procurando por um sapato. Além disso, também gostaria de sugerir outros itens que podem complementar seu estilo:
# 1. Shoes - como você mencionou, um sapato é uma ótima escolha. Existem muitos estilos e tipos para escolher.
# 2. T-shirts - uma camiseta é um item versátil que pode ser usado em diversas ocasiões.
# 3. Jeans - um par de jeans é um clássico que pode ser usado com seu novo sapato.
#
# Se você tiver alguma preferência específica para o sapato, como cor, estilo ou ocasião, ficarei feliz em ajudar a encontrar a melhor opção.
#
# --------------------------------------------------------------------------------
#
# Next speaker: user_test
#
# user_test (to chat_manager):
#
# Desculpa, gostaria de comprar uma camisa.
#
# --------------------------------------------------------------------------------
#
# Next speaker: conversational
#
# conversational (to chat_manager):
#
# Claro, entendo que você está interessado em comprar uma camisa. Para fornecer recomendações mais precisas, poderia me dizer mais sobre o tipo de camisa que você está procurando? Aqui estão algumas perguntas que podem ajudar a direcionar as recomendações:
#
# - **Estilo**: Você está procurando uma camisa social, casual, esportiva ou de alguma outra categoria?
# - **Ocasião**: A camisa será para uso diário, eventos formais, ou para atividades específicas?
# - **Material**: Você prefere alguma fibra em particular, como algodão, poliéster, linho, etc.?
# - **Cor e padrão**: Há alguma cor ou padrão específico que você gostaria?
# - **Tamanho e ajuste**: Você prefere uma camisa mais ajustada ao corpo ou mais soltinha?
#
# Com essas informações, posso solicitar ao agente de recomendação que ofereça opções mais específicas e adequadas às suas necessidades.
#
# --------------------------------------------------------------------------------
#
# Next speaker: user_test
# ChatResult(chat_id=None, chat_history=[{'content': 'Oi tudo bem?', 'name': 'user_test', 'role': 'assistant'}, {'content': 'Hello everyone. We have assembled a great team today to answer questions and solve tasks. In attendance are:\n\nuser_test: You are a human user interacting with conversational and recommendation agents.\nconversational: This agent acts as a social companion and facilitates interactions.\nrecommender: This agent specializes in offering product recommendations.', 'name': 'chat_manager', 'role': 'user'}, {'content': "Olá. Yes, everything is fine, thanks for asking. If you're looking for some great products, I'd like to recommend the following: \n1. Shoes - a good pair can make a big difference in your daily life.\n2. T-shirts - they're versatile and can be dressed up or down.\n3. Jeans - a classic choice that never goes out of style.", 'name': 'recommender', 'role': 'user'}, {'content': "It seems there was a mix-up in my previous response. To clarify, if you're looking for recommendations on specific products like shoes, t-shirts, or jeans, the recommender agent would be best suited to provide detailed suggestions based on your preferences and needs. Could you tell me more about what you're looking for or any specific preferences you have?", 'name': 'conversational', 'role': 'user'}, {'content': "I'm here to help with recommendations. Since you're open to suggestions, I'd like to recommend the following essential items: \n1. Shoes - a comfortable and stylish pair can elevate your outfit.\n2. T-shirts - they're perfect for casual wear and can be easily paired with other items.\n3. Jeans - a classic and versatile choice that can be dressed up or down.\n\nPlease let me know if you have any specific preferences, such as color, style, or occasion, and I'll be happy to provide more tailored suggestions.", 'name': 'recommender', 'role': 'user'}, {'content': 'Gostaria de saber mais sobre os produtos disponiveis.', 'name': 'user_test', 'role': 'assistant'}, {'content': 'Claro, posso ajudar com isso! Para fornecer recomendações mais precisas, poderia me dizer mais sobre o que você está procurando? Por exemplo:\n\n1. **Calçados**: Você prefere sapatos para ocasiões formais, tênis para esportes ou sapatos casuais para o dia a dia?\n2. **Camisetas**: Você está procurando algo casual, com estampas, ou algo mais básico e elegante?\n3. **Jeans**: Você prefere um jeans mais justo, reto ou com um corte mais solto? E para que tipo de ocasião você pretende usar?\n\nCom essas informações, posso solicitar ao agente de recomendação que ofereça opções mais específicas e adequadas às suas necessidades.', 'name': 'conversational', 'role': 'user'}, {'content': 'Gostaria de comprar um sapato.', 'name': 'user_test', 'role': 'assistant'}, {'content': 'Entendo que você está procurando por um sapato. Além disso, também gostaria de sugerir outros itens que podem complementar seu estilo:\n1. Shoes - como você mencionou, um sapato é uma ótima escolha. Existem muitos estilos e tipos para escolher.\n2. T-shirts - uma camiseta é um item versátil que pode ser usado em diversas ocasiões.\n3. Jeans - um par de jeans é um clássico que pode ser usado com seu novo sapato.\n\nSe você tiver alguma preferência específica para o sapato, como cor, estilo ou ocasião, ficarei feliz em ajudar a encontrar a melhor opção.', 'name': 'recommender', 'role': 'user'}, {'content': 'Desculpa, gostaria de comprar uma camisa.', 'name': 'user_test', 'role': 'assistant'}, {'content': 'Claro, entendo que você está interessado em comprar uma camisa. Para fornecer recomendações mais precisas, poderia me dizer mais sobre o tipo de camisa que você está procurando? Aqui estão algumas perguntas que podem ajudar a direcionar as recomendações:\n\n- **Estilo**: Você está procurando uma camisa social, casual, esportiva ou de alguma outra categoria?\n- **Ocasião**: A camisa será para uso diário, eventos formais, ou para atividades específicas?\n- **Material**: Você prefere alguma fibr ...
