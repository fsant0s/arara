# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os

ROOT_DIR = os.path.abspath('..')
sys.path.append(ROOT_DIR)
os.chdir(ROOT_DIR)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from neuron.neurons import Neuron, User
from neuron.capabilities.memory import ListMemory, MemoryContent
import os

# %%
llm_config = {
    "config_list": [
        {
            "client": "groq",
            "temperature": 0.0,
            "model": "llama-3.3-70b-versatile",
            "api_key": os.getenv("GROQ_API_KEY")
        }
    ]
}

# Initialize memory
memory = ListMemory(name="chat_history")
memory.add(MemoryContent(content="User prefers peanut meals only"))
memory.add(MemoryContent(content="User is allergic to peanuts"))

def get_recipe(diet_type: str = "standard") -> str:
    """
    Returns a recipe suggestion based on the specified diet type.

    Parameters:
    - diet_type (str): The dietary category of the recipe.
        Options:
        - "vegan": Plant-based, no animal products.
        - "peanut": Contains peanuts.
        - "standard": Includes meat and/or dairy.

    Returns:
    - str: A string describing a single recipe corresponding to the diet type.
    """

    if diet_type.lower() == "vegan":
        return (
            "Chickpea pasta with sautéed vegetables and olive oil — a nutritious, fully plant-based meal."
        )

    elif diet_type.lower() == "peanut":
        return (
            "Thai peanut stir-fry with tofu — savory and rich, made with peanut sauce and rice noodles."
        )

    elif diet_type.lower() == "standard":
        return (
            "Creamy chicken alfredo — grilled chicken tossed in a rich cream and parmesan sauce."
        )

    else:
        return f"Sorry, no recipe found for diet type '{diet_type}'."

user = User(
    name="user"
)

assistant_agent = Neuron(
    name="assistant_agent",
    llm_config=llm_config,
    tools=[get_recipe],
    memory=[memory],
)

# %%
chat_result = user.initiate_chat(
    assistant_agent,
    message="Can you recommend me something for dinner?"
)
# Out:
# user ⟶ assistant_agent:
# Can you recommend me something for dinner?
# model_result finish_reason='function_calls' content=[FunctionCall(id='call_nrqg', arguments='{"diet_type": "standard"}', name='get_recipe')] usage=RequestUsage(prompt_tokens=510, completion_tokens=15, total_tokens=525) cached=False logprobs=None thought=None response_id='chatcmpl-0771e23a-2d1e-4fd4-94f9-82dcea96940f' cost=0.00031275 model_name='llama-3.3-70b-versatile' message_retrieval_function=<bound method GroqClient.message_retrieval of <neuron.capabilities.clients.models.groq.GroqClient object at 0x000002D0B067B620>> config_id=0 pass_filter=True
# assistant_agent ⟶ user:
# 🛠️ Suggested Function Call: get_recipe
#  Arguments:
#  {
#    "diet_type": "standard"
#  }
# assistant_agent ⟶ user:
# ✅ Function Execution Result: get_recipe
#  Result:
#  Creamy chicken alfredo — grilled chicken tossed in a rich cream and parmesan sauce.
# assistant_agent ⟶ user:
# Creamy chicken alfredo — grilled chicken tossed in a rich cream and parmesan sauce.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 chat_result = user.initiate_chat(
#       2     assistant_agent,
#       3     message="Can you recommend me something for dinner?"
#       4 )
#
# File c:\Users\FS-Ma\OneDrive\Documents\projects\neuron\neuron\neurons\neuron.py:371, in Neuron.initiate_chat(self, recipient, should_clear_history, silent, message, summary_method, summary_args, cache, **kwargs)
#     368     agent.client_cache = cache
#     370 prepare_chat(self, recipient, should_clear_history)
# --> 371 self.send(message, recipient, silent=silent, request_reply=True)
#     373 summary = self._summarize_chat(
#     374      summary_method,
#     375     summary_args,
#     376        recipient,
#     377     cache=cache,
#     378 )
#     380 for agent in [self, recipient]:
#
# File c:\Users\FS-Ma\OneDrive\Documents\projects\neuron\neuron\neurons\neuron.py:420, in Neuron.send(self, message, recipient, request_reply, silent)
#     416 if not valid:
#     417     raise ValueError(
#     418         "Message can't be converted into a valid ChatCompletion message. Either content or function_call must be provided."
#     419     )
# --> 420 recipient.receive(message, self, request_reply, silent)
#
# File c:\Users\FS-Ma\OneDrive\Documents\projects\neuron\neuron\neurons\neuron.py:458, in Neuron.receive(self, message, sender, request_reply, silent)
#     456 if isinstance(reply, Response):
#     457     request_reply = True
# --> 458 self.send(reply, sender, silent=silent, request_reply=request_reply)
#
# File c:\Users\FS-Ma\OneDrive\Documents\projects\neuron\neuron\neurons\neuron.py:420, in Neuron.send(self, message, recipient, request_reply, silent)
#     416 if not valid:
#     417     raise ValueError(
#     418         "Message can't be converted into a valid ChatCompletion message. Either content or function_call must be provided."
#     419     )
# --> 420 recipient.receive(message, self, request_reply, silent)
#
# File c:\Users\FS-Ma\OneDrive\Documents\projects\neuron\neuron\neurons\neuron.py:453, in Neuron.receive(self, message, sender, request_reply, silent)
#     444 if (
#     445     (request_reply is False
#     446     or request_reply is None
#     447     and self.reply_at_receive[sender] is False)
#     448     or self._conversation_terminated[sender] # User typed "exit"
#     449 ):
#     450     return
# --> 453 for reply in self.generate_reply(sender=sender):
#     454     # It is the final yield. If the type is Response, it marks the generator's last yield.
#     455     request_reply = False
#     456     if isinstance(reply, Response):
#
# File c:\Users\FS-Ma\OneDrive\Documents\projects\neuron\neuron\neurons\neuron.py:501, in Neuron.generate_reply(self, messages, sender, **kwargs)
#     499 reply_func = entry["reply_func"]
#     500 config = entry["config"]
# --> 501 for response_batch in reply_func(self, messages=messages, sender=sender, config=config):
#     502     for is_final, reply in response_batch:
#     503         if not is_final:
#
# File c:\Users\FS-Ma\OneDrive\Documents\projects\neuron\neuron\neurons\neuron.py:753, in Neuron.check_termination_and_human_reply(self, messages, sender, config)
#     750 sender_name = "the sender" if sender is None else sender.name
#     752 if self.human_input_mode == "ALWAYS":
# --> 753     reply = self.get_human_input(
#     754         f"Replying as {self.name}. Provide feedback to {sender_name}. Press enter to skip and use auto-reply, or type 'exit' to end the conversation: "
#     755     )
#     756     no_human_input_msg = "NO HUMAN INPUT RECEIVED." if not reply else ""
#     757     # if the human input is empty, and the message is a termination message, then we will terminate the conversation
#
# File c:\Users\FS-Ma\OneDrive\Documents\projects\neuron\neuron\neurons\neuron.py:814, in Neuron.get_human_input(self, prompt)
#     802 """Get human input.
#     803
#     804 Override this method to customize the way to get human input.
#    (...)
#     810     str: human input.
#     811 """
#     812 iostream = IOStream.get_default()
# --> 814 reply = iostream.input(prompt)
#     815 self._human_input.append(reply)
#     816 return reply
#
# File c:\Users\FS-Ma\OneDrive\Documents\projects\neuron\neuron\io\console.py:37, in IOConsole.input(self, prompt, password)
#      35 if password:
#      36     return getpass.getpass(prompt if prompt != "" else "Password: ")
# ---> 37 return input(prompt)
#
# File c:\Users\FS-Ma\OneDrive\Documents\projects\neuron\.venv\Lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File c:\Users\FS-Ma\OneDrive\Documents\projects\neuron\.venv\Lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
