# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os

ROOT_DIR = os.path.abspath('..')
sys.path.append(ROOT_DIR)
os.chdir(ROOT_DIR)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from neuron.neurons import User, Neuron
import os
# Out:
# c:\Users\FS-Ma\OneDrive\Documents\projects\neuron\.venv\Lib\site-packages\pydantic\_internal\_fields.py:132: UserWarning: Field "model_name" in CreateResult has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(

# %%
llm_config = {
    "config_list": [
        {
            "client": "groq",
            "temperature": 0.0,
            "model": "llama-3.3-70b-versatile",
            "api_key": os.getenv("GROQ_API_KEY")
        }
    ]
}

from typing import Annotated, Literal

Operator = Literal["+", "-", "*", "/"]

def exchange_rate(base_currency: str, quote_currency: str) -> float:
    """
    Returns the exchange rate between two currencies.

    Parameters:
    - base_currency (str): The currency you want to convert from (e.g., "USD").
    - quote_currency (str): The currency you want to convert to (e.g., "EUR").

    Returns:
    - float: The exchange rate from base_currency to quote_currency.

    Raises:
    - ValueError: If the currency pair is unknown or not supported.
    """

    # If the base and quote currencies are the same, return 1.0
    if base_currency == quote_currency:
        return 1.0

    # Conversion from USD to EUR (example rate)
    elif base_currency == "USD" and quote_currency == "EUR":
        return 1 / 1.09

    # Conversion from EUR to USD (example rate)
    elif base_currency == "EUR" and quote_currency == "USD":
        return 1.1

    # Raise error if the currency pair is not recognized
    else:
        raise ValueError(f"Unknown currencies {base_currency}, {quote_currency}")


def exchange_rate(base_currency: str, quote_currency: str) -> float:
    """
    Returns the exchange rate between two currencies.

    Parameters:
    - base_currency (str): The currency you want to convert from (e.g., "USD").
    - quote_currency (str): The currency you want to convert to (e.g., "EUR").

    Returns:
    - float: The exchange rate from base_currency to quote_currency.

    Raises:
    - ValueError: If the currency pair is unknown or not supported.
    """

    # If the base and quote currencies are the same, return 1.0
    if base_currency == quote_currency:
        return 1.0

    # Conversion from USD to EUR (example rate)
    elif base_currency == "USD" and quote_currency == "EUR":
        return 1 / 1.09

    # Conversion from EUR to USD (example rate)
    elif base_currency == "EUR" and quote_currency == "USD":
        return 1.1

    # Raise error if the currency pair is not recognized
    else:
        raise ValueError(f"Unknown currencies {base_currency}, {quote_currency}")


def exchange_rate(base_currency: float, quote_currency) -> float:
    """
    Returns the exchange rate between two currencies.

    Parameters:
    - base_currency (str): The currency from which to convert.
    - quote_currency (str): The currency to convert to.

    Returns:
    - float: The exchange rate from base_currency to quote_currency.

    Raises:
    - ValueError: If the currency pair is unknown.
    """

    # If the base and quote currencies are the same, the exchange rate is 1
    if base_currency == quote_currency:
        return 1.0

    # Conversion from USD to EUR (example rate)
    elif base_currency == "USD" and quote_currency == "EUR":
        return 1 / 1.09

    # Conversion from EUR to USD (example rate)
    elif base_currency == "EUR" and quote_currency == "USD":
        return 1.1

    # Raise an error for unknown currency pairs
    else:
        raise ValueError(f"Unknown currencies {base_currency}, {quote_currency}")


def currency_calculator(
        base_amount: float,
        base_currency:str,
        quote_currency:str,
) -> str:
    """
    Converts a monetary amount from one currency to another.

    Parameters:
    - base_amount (float): The amount of money in the base currency.
    - base_currency (str): The currency in which the base_amount is expressed.
    - quote_currency (str): The target currency to convert the base_amount into.

    Returns:
    - str: A string representing the converted amount followed by the quote currency.
    """

    # Get the converted amount using the exchange rate
    quote_amount = exchange_rate(base_currency, quote_currency) * float(base_amount)

    # Return the converted amount as a formatted string
    return f"{quote_amount} {quote_currency}"


# Let's first define the assistant agent that suggests tool calls.
user = User(
    name="user"
)

# The user proxy agent is used for interacting with the assistant agent
# and executes tool calls.
math = Neuron(
    name="math",
    llm_config=llm_config,
    system_message="You are a helpful AI assistant. "
    "You can help with simple calculations. "
    "Think step by step and use the calculator tool when needed." \
    "if the user request anything other than calculation, reply gently.'",
    tools = [currency_calculator],
    reflect_on_tool_use=False,
    tool_call_summary_format="Tool call: {result}",
)

# %%
chat_result = user.initiate_chat(math, message="How much is 123.45 USD in EUR?")
# Out:
# user (to math):
#
# How much is 123.45 USD in EUR?
#
# --------------------------------------------------------------------------------
# c:\Users\FS-Ma\OneDrive\Documents\projects\neuron\neuron\logger\logger_utils.py:9: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.datetime.utcnow().strftime("%Y-%m-%d %H:%M:%S.%f")
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 chat_result = user.initiate_chat(math, message="How much is 123.45 USD in EUR?")
#
# File c:\Users\FS-Ma\OneDrive\Documents\projects\neuron\neuron\neurons\neuron.py:339, in Neuron.initiate_chat(self, recipient, should_clear_history, silent, message, summary_method, summary_args, cache, **kwargs)
#     337 prepare_chat(self, recipient, should_clear_history)
#     338 msg2send = TextMessage(content=message, chat_messages=message, source="user")
# --> 339 self.send(msg2send, recipient, silent=silent)
#     341 summary = self._summarize_chat(
#     342     summary_method,
#     343     summary_args,
#     344     recipient,
#     345     cache=cache,
#     346 )
#     348 for agent in [self, recipient]:
#
# File c:\Users\FS-Ma\OneDrive\Documents\projects\neuron\neuron\neurons\neuron.py:383, in Neuron.send(self, message, recipient, request_reply, silent)
#     381 valid = append_oai_message(self, message, "assistant", recipient, is_sending=True)
#     382 if valid:
# --> 383     recipient.receive(message, self, request_reply, silent)
#     384 else:
#     385     raise ValueError(
#     386         "Message can't be converted into a valid ChatCompletion message. Either content or function_call must be provided."
#     387     )
#
# File c:\Users\FS-Ma\OneDrive\Documents\projects\neuron\neuron\neurons\neuron.py:419, in Neuron.receive(self, message, sender, request_reply, silent)
#     417 reply = self.generate_reply(messages=chat_messages(self, sender), sender=sender)
#     418 if reply is not None:
# --> 419     self.send(reply, sender, silent=silent)
#
# File c:\Users\FS-Ma\OneDrive\Documents\projects\neuron\neuron\neurons\neuron.py:380, in Neuron.send(self, message, recipient, request_reply, silent)
#     359 def send(
#     360     self,
#     361     message: Union[Dict, str],
#    (...)
#     364     silent: Optional[bool] = False,
#     365 ):
#     366     """
#     367     Send a message to another neuron.
#     368
#    (...)
#     378         Union[str, Dict, None]: The reply from the recipient if requested.
#     379     """
# --> 380     message = process_message_before_send(self, message, recipient, silent)
#     381     valid = append_oai_message(self, message, "assistant", recipient, is_sending=True)
#     382     if valid:
#
# File c:\Users\FS-Ma\OneDrive\Documents\projects\neuron\neuron\neurons\helpers\message_processing.py:22, in process_message_before_send(self, message, recipient, silent)
#      18 def process_message_before_send(
#      19     self: BaseNeuron, message: [Response | TextMessage], recipient: BaseNeuron, silent: bool
#      20 ) -> Union[Dict, str]:
#      21     """Process the message before sending it to the recipient."""
# ---> 22     message = message.content if isinstance(message, TextMessage) else message.chat_message.content
#      23     hook_list = self.hook_lists["process_message_before_send"]
#      24     for hook in hook_list:
#
# AttributeError: 'generator' object has no attribute 'chat_message'
